# %% [markdown]
# # Big O Notation with Pandas and Matplotlib
# Make a new Jupyter notebook named big_o_pandas.ipynb
# Create a single dataframe that holds the following values.
# Columns to create:
# - Create a column named "x" that holds `np.arange(1, 100)`
# - Create a column named "constant" that holds the result of $y = 0x + 1$
# - Create a column named "logarithmic" that holds the result of $y = log(x)$
# - Create a column named "linear" that holds the result of $y = x$
# - Create a column named "loglinear" that holds the result of $y = x * log(x)$
# - Create a column named "quadratic" that holds the result of $y = x^2$
# - Create a column named "exponential" that holds the result of $y = 2^x$
# - Create a column named "factorial" that holds the result of $y = x!$
#
#
# Now use the data from your dataframe to create a chart with the following information and curves
# - Title your chart "Big O Notation"
# - Label your x axis "Elements"
# - Label your y axis "Operations"
# - Label your curves or make a legend for the curves
# - Use LaTex notation where possible
#
# Curves to graph
# - $y = 0x + 1$ and label the curve "O(1)"
# - $y = log(x)$ and label the curve "O(log n)"
# - $y = x$ and label the curve "O(n)"
# - $y = x * log(x)$ and label it "O(n log n)"
# - $y = x^2$ and label it "O(n^2)"
# - $y = 2^x$ and label it "O(2^n)"
# - $y = n!$ and label is "O(n!)"

# %%
import pandas as pd
import numpy as np
import math
# %matplotlib inline
import matplotlib.pyplot as plt

x = np.arange(1,100)
constant = [(0 * n) + 1 for n in x]
logarithmic = [math.log(n) for n in x]
linear = [n for n in x]
loglinear = [(n * math.log(n)) for n in x]
quadratic = [n ** 2 for n in x]
exponential = [2 ** n for n in x]
factorial = [(math.factorial(n)) for n in x]


df = pd.DataFrame({'x': x,
                   'constant': constant,
                   'logarithmic': logarithmic,
                   'linear': linear,
                   "loglinear": loglinear,
                   "quadratic": quadratic,
                   "exponential": exponential,
                   "factorial": factorial,
                   
                  })

# %%
df
# Out:
#      x  constant  logarithmic  linear   loglinear  quadratic  exponential  \
# 0    1         1     0.000000       1    0.000000          1            2
# 1    2         1     0.693147       2    1.386294          4            4
# 2    3         1     1.098612       3    3.295837          9            8
# 3    4         1     1.386294       4    5.545177         16           16
# 4    5         1     1.609438       5    8.047190         25           32
# ..  ..       ...          ...     ...         ...        ...          ...
# 94  95         1     4.553877      95  432.618305       9025            0
# 95  96         1     4.564348      96  438.177426       9216            0
# 96  97         1     4.574711      97  443.746965       9409            0
# 97  98         1     4.584967      98  449.326813       9604            0
# 98  99         1     4.595120      99  454.916865       9801            0
#
#                                             factorial
# 0                                                   1
# 1                                                   2
# 2                                                   6
# 3                                                  24
# 4                                                 120
# ..                                                ...
# 94  1032997848823905926259970209939472709539774634...
# 95  9916779348709496892095714015418938011581836486...
# 96  9619275968248211985332842594956369871234381391...
# 97  9426890448883247745626185743057242473809693764...
# 98  9332621544394415268169923885626670049071596826...
#
# [99 rows x 8 columns]

# %%
df.describe()
# Out:
#                x  constant  logarithmic     linear   loglinear    quadratic  \
# count  99.000000      99.0    99.000000  99.000000   99.000000    99.000000
# mean   50.000000       1.0     3.627618  50.000000  205.012373  3316.666667
# std    28.722813       0.0     0.927587  28.722813  137.518657  2964.596937
# min     1.000000       1.0     0.000000   1.000000    0.000000     1.000000
# 25%    25.500000       1.0     3.238486  25.500000   82.591203   650.500000
# 50%    50.000000       1.0     3.912023  50.000000  195.601150  2500.000000
# 75%    74.500000       1.0     4.310777  74.500000  321.156213  5550.500000
# max    99.000000       1.0     4.595120  99.000000  454.916865  9801.000000
#
#         exponential
# count  9.900000e+01
# mean   0.000000e+00
# std    1.075836e+18
# min   -9.223372e+18
# 25%    0.000000e+00
# 50%    8.192000e+03
# 75%    2.061584e+11
# max    4.611686e+18

# %%
df.plot()
plt.ylabel("Operations")
plt.xlabel("Elements")
plt.title("Big O Notation")
plt.legend()
plt.yscale("log")

plt.show()
