# %% [markdown]
# ## Matplotlib exercises
#
# Q1:Use matplotlib to plot the following equation:
#
# $y = x^2 - x + 2$
#
# You'll need to write the code that generates the x and y points and add an anotation for the point ```0,0``` the origin

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = np.array(range(100))
y = (x ** 2) - (x+2)

plt.plot(x,y)

plt.text(0,0, '(0,0)', fontsize=10)
plt.show()

# %%
x = range(1, 25)
y = [(n ** 2) - (n + 2) for n in x]

plt.title("$y=x^2 -x + 2$")
plt.xlabel("x")
plt.ylabel("y", rotation=0)

plt.annotate("Origin", xy=(0,0), xytext=(0, 125), arrowprops={'facecolor': 'blue'})
plt.plot(y)
plt.show()

# %% [markdown]
# ### Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %%
x = list(range(1000))
y = [math.sqrt(n) for n in x]

plt.title('Plot of y = $\sqrt{x}$')
plt.plot(y)
plt.show()

# %%
x = list(range(1000))
y = [n ** 3 for n in x]
plt.title("Plot looking at y = $x ^ 3$")
plt.plot(x,y)
plt.show()

# %%
x = list(range(1000))
y = [math.tan(n) for n in x]
plt.title("Plot of y = $tan(x)$")
plt.plot(x,y)
plt.show()

# %%
x = list(range(40))
y = [2 ** n for n in x]
plt.title("Plot of y = $2^x$ ")
plt.plot(x,y)
plt.show()

# %% [markdown]
# Q4 Combine the figures you created in the last step into one large figure with 4 subplots

# %%
n_rows = 2
n_cols = 2
x = range(1, 50)
plt.subplots_adjust(hspace=0.5)


plt.suptitle("Subplots of the above 4 exercises")

plt.subplot(n_rows, n_cols, 1)
y = [2 ** n for n in x]
plt.title("Plot of y = $2^n$ ")
plt.plot(x,y)


plt.subplot(n_rows, n_cols, 2)
y = [math.tan(n) for n in x]
plt.title("Plot of y = $tan(x)$")
plt.plot(x,y)


plt.subplot(n_rows, n_cols, 3)
y = [n ** 3 for n in x]
plt.title("Plot looking at y = $n ^ 3$")
plt.plot(x,y)


plt.subplot(n_rows, n_cols, 4)
y = [math.sqrt(n) for n in x]

plt.title('Plot of y = $\sqrt{x}$')
plt.plot(y)


plt.show()

# %% [markdown]
# Q4 Comine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend.

# %%
x = range(10)
y1 = [2 ** n for n in x]
plt.figure(figsize=(16,6))
y2 = [math.tan(n) for n in x]
y3 = [n ** 3 for n in x]
y4 = [math.sqrt(n) for n in x]

plt.plot(x,y1, label = "Plot of y = $2^n$ ")
plt.plot(x,y2, label= "Plot of y = tan(x)")
plt.plot(x, y3, label = "Plot looking at y = $n ^3$" )
plt.plot(x, y4, label = 'Plot of y = $\sqrt{x}$')

plt.legend()
plt.title("Combined graph for matplot exercises")
plt.xlabel('$x$')


plt.show()

# %% [markdown]
# *Bonus*
#
# Write the code necessary to write your name on a chart. Use box letters.
#
# *Extra Bonus*: use curves for letters in your name that have curves in them.

# %%
x = [4,12,3.14,2,4]
y = [n ** 2 for n in x]
plt.scatter(x,y)
plt.xticks([4,12,3.14,2,4], ['one','two','$\pi$', 'four'])
plt.show()
